# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
from tqdm import tqdm
from vae2 import VariationalAutoEncoder, kl_loss_function, mse_loss_function, sample

# %%
device = torch.device('mps')
batch_size = 120
epochs = 30

# %%
transform = transforms.Compose([
    transforms.ToTensor(), 
    transforms.Resize((32, 32)) 
])

dataset = datasets.MNIST(root='./data', train=True, transform=transform, download=True)

# %%
dataloader = DataLoader(dataset=dataset, batch_size=batch_size, shuffle=True)

# %%
# Verificar que el dataloader funciona
for batch_idx, (data, target) in enumerate(dataloader):
    print(f"Lote {batch_idx}: Tamaño de entrada: {data.size()}, Tamaño de etiquetas: {target.size()}")
    break  # Solo imprimir el primer lote
# Out:
# Lote 0: Tamaño de entrada: torch.Size([120, 1, 32, 32]), Tamaño de etiquetas: torch.Size([120])

# %%
image_shape = list(data.shape)
image_shape
# Out:
# [120, 1, 32, 32]

# %%
def VAE_train(model, dataloader, optimizer, epochs):
    for epoch in range(epochs):
        mse_loss_sum = 0
        kl_loss_sum = 0
        loss_sum = 0
        
        pbar = tqdm(enumerate(dataloader), total=len(dataloader))
        pbar.set_description(f"Epoch {epoch} - Training")
        for i, batch in pbar:
            x, _ = batch
            x = x.to(device)
            mean, log_var = model.encoder(x)
            z_sample = sample(mean, log_var)
            x_bar = model.decoder(z_sample)

            mse_loss = mse_loss_function(x, x_bar)
            kl_loss = kl_loss_function(mean, log_var)
            loss = torch.mean(mse_loss + kl_loss)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            mse_loss_sum += mse_loss.item()
            kl_loss_sum += kl_loss.item()
            loss_sum += loss.item()
            pbar.set_postfix({'mse_loss' : mse_loss_sum / (i+1), 'kl_loss' : kl_loss_sum / (i+1), 'loss' : loss_sum /(i+1)})

    return model

# %%
model = VariationalAutoEncoder(latent_dim=2, image_shape=image_shape).to(device)
optimizer = torch.optim.Adam(model.parameters())
model.train()
model = VAE_train(model, dataloader, optimizer, epochs=epochs)
# Out:
# Epoch 0 - Training: 100%|██████████| 500/500 [00:12<00:00, 40.71it/s, mse_loss=5.88e+3, kl_loss=355, loss=6.24e+3]
# Epoch 1 - Training: 100%|██████████| 500/500 [00:11<00:00, 42.29it/s, mse_loss=4.69e+3, kl_loss=472, loss=5.16e+3]
# Epoch 2 - Training: 100%|██████████| 500/500 [00:11<00:00, 41.68it/s, mse_loss=4.45e+3, kl_loss=514, loss=4.96e+3]
# Epoch 3 - Training: 100%|██████████| 500/500 [00:11<00:00, 42.56it/s, mse_loss=4.29e+3, kl_loss=540, loss=4.83e+3]
# Epoch 4 - Training: 100%|██████████| 500/500 [00:10<00:00, 46.38it/s, mse_loss=4.19e+3, kl_loss=557, loss=4.75e+3]
# Epoch 5 - Training: 100%|██████████| 500/500 [00:10<00:00, 47.99it/s, mse_loss=4.12e+3, kl_loss=569, loss=4.69e+3]
# Epoch 6 - Training: 100%|██████████| 500/500 [00:10<00:00, 48.07it/s, mse_loss=4.06e+3, kl_loss=578, loss=4.64e+3]
# Epoch 7 - Training: 100%|██████████| 500/500 [00:10<00:00, 48.15it/s, mse_loss=4.02e+3, kl_loss=586, loss=4.6e+3]
# Epoch 8 - Training: 100%|██████████| 500/500 [00:10<00:00, 47.95it/s, mse_loss=3.97e+3, kl_loss=594, loss=4.57e+3]
# Epoch 9 - Training: 100%|██████████| 500/500 [00:10<00:00, 48.09it/s, mse_loss=3.93e+3, kl_loss=600, loss=4.53e+3]
# Epoch 10 - Training: 100%|██████████| 500/500 [00:10<00:00, 48.00it/s, mse_loss=3.9e+3, kl_loss=606, loss=4.51e+3]
# Epoch 11 - Training: 100%|██████████| 500/500 [00:10<00:00, 48.01it/s, mse_loss=3.88e+3, kl_loss=609, loss=4.49e+3]
# Epoch 12 - Training: 100%|██████████| 500/500 [00:10<00:00, 48.01it/s, mse_loss=3.85e+3, kl_loss=614, loss=4.47e+3]
# Epoch 13 - Training: 100%|██████████| 500/500 [00:10<00:00, 48.08it/s, mse_loss=3.84e+3, kl_loss=617, loss=4.45e+3]
# Epoch 14 - Training: 100%|██████████| 500/500 [00:10<00:00, 48.23it/s, mse_loss=3.82e+3, kl_loss=619, loss=4.43e+3]
# Epoch 15 - Training: 100%|██████████| 500/500 [00:10<00:00, 47.93it/s, mse_loss=3.8e+3, kl_loss=622, loss=4.42e+3]
# Epoch 16 - Training: 100%|██████████| 500/500 [00:10<00:00, 48.17it/s, mse_loss=3.78e+3, kl_loss=624, loss=4.41e+3]
# Epoch 17 - Training: 100%|██████████| 500/500 [00:10<00:00, 48.01it/s, mse_loss=3.77e+3, kl_loss=628, loss=4.39e+3]
# Epoch 18 - Training: 100%|██████████| 500/500 [00:10<00:00, 47.88it/s, mse_loss=3.75e+3, kl_loss=631, loss=4.38e+3]
# Epoch 19 - Training: 100%|██████████| 500/500 [00:10<00:00, 48.04it/s, mse_loss=3.74e+3, kl_loss=632, loss=4.37e+3]
# Epoch 20 - Training: 100%|██████████| 500/500 [00:10<00:00, 47.95it/s, mse_loss=3.72e+3, kl_loss=633, loss=4.36e+3]
# Epoch 21 - Training: 100%|██████████| 500/500 [00:10<00:00, 47.88it/s, mse_loss=3.71e+3, kl_loss=637, loss=4.35e+3]
# Epoch 22 - Training: 100%|██████████| 500/500 [00:10<00:00, 48.30it/s, mse_loss=3.7e+3, kl_loss=637, loss=4.34e+3]
# Epoch 23 - Training: 100%|██████████| 500/500 [00:10<00:00, 47.99it/s, mse_loss=3.69e+3, kl_loss=637, loss=4.33e+3]
# Epoch 24 - Training: 100%|██████████| 500/500 [00:10<00:00, 48.29it/s, mse_loss=3.68e+3, kl_loss=640, loss=4.32e+3]
# Epoch 25 - Training: 100%|██████████| 500/500 [00:10<00:00, 48.51it/s, mse_loss=3.67e+3, kl_loss=642, loss=4.31e+3]
# Epoch 26 - Training: 100%|██████████| 500/500 [00:10<00:00, 48.14it/s, mse_loss=3.66e+3, kl_loss=642, loss=4.31e+3]
# Epoch 27 - Training: 100%|██████████| 500/500 [00:10<00:00, 47.89it/s, mse_loss=3.65e+3, kl_loss=644, loss=4.3e+3]
# Epoch 28 - Training: 100%|██████████| 500/500 [00:10<00:00, 48.10it/s, mse_loss=3.65e+3, kl_loss=646, loss=4.29e+3]
# Epoch 29 - Training: 100%|██████████| 500/500 [00:10<00:00, 48.29it/s, mse_loss=3.64e+3, kl_loss=648, loss=4.29e+3]

# %%
import matplotlib.pyplot as plt

x = data[0]
plt.imshow(x.permute(1, 2, 0))

# %%
model.eval()

x = x.to(device)
mean, log_var = model.encoder(x)
z_sample = sample(mean, log_var)
x_bar = model.decoder(z_sample)

plt.imshow(x_bar[0].permute(1, 2, 0).cpu().detach().numpy())
